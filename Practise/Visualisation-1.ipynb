# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
data_visual = pd.read_csv("./titanic_train.csv")
data_visual.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
# Creating a line plot
x = [1,2,3,4,5]
y = [3,4,52,3,5]
plt.plot(x, y, color='purple', linestyle='-', marker='o', linewidth=2, markersize=9)
plt.xlabel("X-axis")
plt.ylabel("Y-axis")
plt.title("Basic line plot")
# Out:
# Text(0.5, 1.0, 'Basic line plot')

# %%
## Creating multiple plots
x = [1,2,3,4,5,6,7,8]
y1 = [12,10,16,8,21,23,25,14]
y2 = [2,5,9,21,11,23,10,18]

plt.figure(figsize=(10,3))

plt.subplot(1,2,1)  # One row and 2 column
plt.plot(x,y1,color='blue', marker="o", markerfacecolor='red')
plt.yticks([10,15,20,25])
plt.title('Plot-1')

plt.subplot(1,2,2)  # One row and 2 column
plt.plot(x,y2,color='blue', marker="o", markerfacecolor='red')
plt.yticks([0,5,10,15,20,25])
plt.title('Plot-2')
# Out:
# Text(0.5, 1.0, 'Plot-2')

# %%
[(lambda i: i+2)(i) for i in x]
# Out:
# [3, 4, 5, 6, 7, 8, 9, 10]

# %%
x1 = ['a', 'b', 'c', 'd', 'e', 'f', 'g', 'h']

plt.bar(x1, y1, color='purple')
# Out:
# <BarContainer object of 8 artists>

# %%
data_x = [12,42,3,12,33,2,4,5,23,1,12,43,53]

plt.hist(data_x, bins=5, color='orange', edgecolor='black')
# Out:
# (array([5., 3., 1., 2., 2.]),
#  array([ 1. , 11.4, 21.8, 32.2, 42.6, 53. ]),
#  <BarContainer object of 5 artists>)

# %%
labels = ['a', 'b', 'c', 'd', 'e', 'f', 'g', 'h']
size = y1
explode= (0,0,0,1,0,0,0,0)

plt.pie(size, labels=labels, autopct="%1.1f%%", shadow=True, startangle=90, explode=explode)

# %%
labels = ['a', 'b', 'c', 'd', 'e', 'f', 'g', 'h']
size = y1
