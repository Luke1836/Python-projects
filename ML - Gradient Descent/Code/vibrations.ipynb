# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("../Source/Sound-and-vibrations.csv")
data.head()

# %%
x = data.iloc[:,0]
y = data.iloc[:,1]

plt.scatter(x,y)

plt.show()
